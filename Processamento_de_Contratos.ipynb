# %%
## Carga de Contrato
import pandas as pd
import numpy as np
from datetime import datetime
import os
import sys
from io import StringIO

# Configuração dos caminhos dos arquivos
planilha_destino = r"C:\Users\lz6321\Downloads\carga_dados_contratos_sofi.xlsx"  # Arquivo a ser preenchido
planilha_fonte1 = r"C:\Users\lz6321\Downloads\contratos 2025.xlsm"   # Primeira fonte de dados
planilha_fonte2 = r"C:\Users\lz6321\Downloads\TI - Previsão Gastos 2025 - Contratos\Cópia de 1 -Comunicação de Dados TI 2025.xlsx"   # Segunda fonte de dados

def converter_para_float(valor_bruto):
    try:
        # Remove os caracteres não numéricos, mantendo pontos e vírgulas
        valor_limpo = ''.join(c for c in str(valor_bruto) if c.isdigit() or c in ',.').strip()
        if not valor_limpo:
            return '0,00'

        # Normaliza o formato do número
        if ',' in valor_limpo:
            valor_limpo = valor_limpo.replace('.', '').replace(',', '.')
        
        # Converte para float
        valor_float = float(valor_limpo)
        
        # Formata o número com pontos para milhares e vírgula para decimais
        return f'{valor_float:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.')
    except (ValueError, AttributeError):
        return '0,00'

def analisar_planilhas():
    # Criar um buffer para capturar a saída
    output = StringIO()
    stdout_original = sys.stdout
    sys.stdout = output
    
    try:
        # Analisando planilha destino
        print('\n=== Análise da Planilha Destino ===')
        df_destino = pd.read_excel(planilha_destino)
        print(f'Número de linhas: {df_destino.shape[0]}')
        print(f'Número de colunas: {df_destino.shape[1]}')
        print('\nColunas disponíveis:')
        for idx, coluna in enumerate(df_destino.columns, 1):
            print(f'{idx}. {coluna}')
        print('\nPrimeiras 5 linhas da planilha destino:')
        print(df_destino.head().to_string())
        
        # Analisando primeira aba da planilha fonte 1
        print('\n=== Análise da Planilha Fonte 1 (Primeira Aba) ===')
        df_fonte1 = pd.read_excel(planilha_fonte1, sheet_name=0)
        print(f'Número de linhas: {df_fonte1.shape[0]}')
        print(f'Número de colunas: {df_fonte1.shape[1]}')
        print('\nColunas disponíveis:')
        for idx, coluna in enumerate(df_fonte1.columns, 1):
            print(f'{idx}. {coluna}')
        print('\nPrimeiras 5 linhas da planilha fonte 1:')
        print(df_fonte1.head().to_string())
        
        # Analisando abas válidas da planilha fonte 2
        print('\n=== Análise da Planilha Fonte 2 ===')
        todas_abas_fonte2 = pd.read_excel(planilha_fonte2, sheet_name=None)
        
        # Removendo as abas que devem ser ignoradas
        abas_ignorar = ['CC', 'Resumo']
        abas_validas = {nome: df for nome, df in todas_abas_fonte2.items() if nome not in abas_ignorar}
        
        print(f'Número de abas válidas: {len(abas_validas)}')
        print('\nAnálise de cada aba válida:')
        
        for nome_aba, df in abas_validas.items():
            print(f'\n--- Aba: {nome_aba} ---')
            print(f'Número de linhas: {df.shape[0]}')
            print(f'Número de colunas: {df.shape[1]}')
            print('Colunas disponíveis:')
            for idx, coluna in enumerate(df.columns, 1):
                print(f'{idx}. {coluna}')
            print('\nPrimeiras 2 linhas desta aba:')
            print(df.head(2).to_string())
            print('-' * 50)
        
        # Restaurar stdout original
        sys.stdout = stdout_original
        
        # Salvar o resultado em um arquivo txt
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        caminho_txt = os.path.join(r"C:\Users\lz6321\Downloads", f'analise_planilhas_{timestamp}.txt')
        
        with open(caminho_txt, 'w', encoding='utf-8') as f:
            f.write(output.getvalue())
        
        print(f'✅ Arquivo de análise salvo em: {caminho_txt}')
        
        return df_destino, df_fonte1, abas_validas
        
    except Exception as e:
        # Restaurar stdout em caso de erro
        sys.stdout = stdout_original
        print(f'❌ Erro ao analisar planilhas: {str(e)}')
        return None, None, None
    finally:
        # Garantir que stdout seja restaurado
        sys.stdout = stdout_original

def formatar_data(data_str):
    """Converte uma data para o formato dd/mm/yyyy"""
    try:
        if not data_str or pd.isna(data_str):
            return ''
        
        # Converte para datetime
        if isinstance(data_str, str):
            try:
                data = pd.to_datetime(data_str, format='%d/%m/%Y')
            except:
                data = pd.to_datetime(data_str)
        else:
            data = pd.to_datetime(data_str)
            
        # Formata para dd/mm/yyyy
        return data.strftime('%d/%m/%Y')
    except Exception as e:
        print(f"Erro ao formatar data '{data_str}': {str(e)}")
        return ''

def processar_dados(df_destino, df_fonte1, abas_fonte2):
    # Colunas que queremos manter no arquivo final
    colunas_desejadas = [
        'nome_contrato', 'nome_fornecedor', 'conta_contabil', 'status',
        'vigencia', 'data_inicial', 'data_final', 'valor_total', 'responsavel',
        'vertical', 'descricao', 'despesa_antecipada', 'frequencia', 'observacoes',
        'descricao_rateio'
    ]
    
    # Criar um DataFrame vazio apenas com as colunas desejadas
    df_final = pd.DataFrame(columns=colunas_desejadas)
    
    # Converter nomes das colunas para minúsculo para facilitar a comparação
    df_fonte1.columns = df_fonte1.columns.str.lower()
    
    print("\nProcessando planilha fonte 1:")
    print("\nColunas disponíveis:")
    print(df_fonte1.columns.tolist())
    
    # Mapeia as colunas da planilha fonte 1 para as colunas desejadas
    for i, row in df_fonte1.iterrows():
        try:
            # Extrai os dados das colunas, usando índice 5 (coluna F) para nome_contrato e nome_fornecedor
            nome_contrato = str(row.iloc[5])
            nome_fornecedor = str(row.iloc[5])  # Mesmo valor que nome_contrato
            
            # Extrai outros dados
            valor_total = converter_para_float(row.get('valor', 0))
            frequencia = str(row.get('frequência', ''))
            
            # Pega as datas e formata
            data_inicial = formatar_data(row.get('inicio', ''))
            data_final = formatar_data(row.get('termino', ''))
            
            conta_contabil = str(row.get('conta contabil', ''))
            descricao = str(row.get('descrição', ''))
            despesa_antecipada = str(row.get('despesa antecipada', ''))
            
            # Pega o responsável diretamente da coluna I (indice 8)
            responsavel = str(row.iloc[8])
            
            # Pega observações da coluna H (índice 7)
            observacoes = str(row.iloc[7])
            
            # Pega descrição de rateio da coluna O (índice 14)
            descricao_rateio = str(row.iloc[14])
            
            print(f"\nProcessando linha {i}:")
            print(f"Fornecedor: {nome_fornecedor}")
            print(f"Valor Total: {valor_total}")
            print(f"Data Inicial: {data_inicial}")
            print(f"Data Final: {data_final}")
            print(f"Conta Contabil: {conta_contabil}")
            print(f"Responsável (da coluna I): {responsavel}")
            print(f"Observações (da coluna H): {observacoes}")
            print(f"Descrição Rateio (da coluna O): {descricao_rateio}")
            print(f"Despesa Antecipada: {despesa_antecipada}")
            
            nova_linha = {
                'nome_contrato': nome_contrato,
                'nome_fornecedor': nome_fornecedor,
                'conta_contabil': conta_contabil,
                'status': 'ATIVO',
                'vigencia': '',  # Agora deixa vigencia vazia
                'data_inicial': data_inicial if data_inicial else '',
                'data_final': data_final if data_final else '',
                'valor_total': valor_total,
                'responsavel': responsavel,
                'vertical': '',  # Agora deixa vertical vazia
                'descricao': descricao if descricao else f'Contrato de serviço {nome_contrato}',
                'despesa_antecipada': despesa_antecipada,
                'frequencia': frequencia if frequencia else 'MENSAL',
                'observacoes': observacoes,  # Adiciona observações da coluna H
                'descricao_rateio': descricao_rateio  # Adiciona descrição de rateio da coluna O
            }
            
            df_final = pd.concat([df_final, pd.DataFrame([nova_linha])], ignore_index=True)
            
        except Exception as e:
            print(f"Erro ao processar linha {i}: {str(e)}")
            continue
    
    # Salvar o resultado em um novo arquivo Excel
    caminho_saida = os.path.join(r'C:\Users\lz6321\Downloads', 'contratos_processados.xlsx')
    df_final.to_excel(caminho_saida, index=False)
    print(f'\n✅ Arquivo processado salvo em: {caminho_saida}')
    
    print('\nPrimeiras linhas do arquivo gerado:')
    print(df_final.head())
    
    return df_final

# Execute estas linhas para analisar as planilhas
df_destino, df_fonte1, abas_fonte2 = analisar_planilhas()

# Processar os dados e gerar o arquivo final
df_final = processar_dados(df_destino, df_fonte1, abas_fonte2)
print('\nPrimeiras linhas do arquivo gerado:')
display(df_final.head())
# Out:
# ✅ Arquivo de análise salvo em: C:\Users\lz6321\Downloads\analise_planilhas_20250611_161437.txt
#
# Processando planilha fonte 1:
#
# Colunas disponíveis:
# ['1-5', 'tema', 'inflação', 'prev', 'gov', 'fornecedor', 'descrição', 'serviço/software/sistema', 'responsável ', 'valor', 'frequência', 'inicio', 'termino', 'despesa antecipada', 'rateio ', 'conta contabil', 'ultima req', 'req antiga', 'diversos', 'juridico', 'atualizado', 'notificado', 'unnamed: 22', 'unnamed: 23']
#
# Processando linha 0:
# Fornecedor: Locaweb
# Valor Total: 90.000,00
# Data Inicial:
# Data Final: 19/10/2023
# Conta Contabil: Comunicacao de Dados - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Hospedagem Servidores + registro domínios nacionais e Internacionais
# Descrição Rateio (da coluna O): 34% MKT 33% DVE  33% EXP
# Despesa Antecipada: Sim e não
#
# Processando linha 1:
# Fornecedor: FAPESP / NIC.BR
# Valor Total: 3.900,00
# Data Inicial:
# Data Final:
# Conta Contabil: Comunicacao de Dados - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Hospedagem Servidores + registro domínios nacionais e Internacionais
# Descrição Rateio (da coluna O): Conforme necessidade do setor se vai querer renovar (mkt, vds e dve)
# Despesa Antecipada: Não
#
# Processando linha 2:
# Fornecedor: 101 Domains
# Valor Total: 2.912,00
# Data Inicial:
# Data Final:
# Conta Contabil: Comunicacao de Dados - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Domínios internacionais da Melissa
# Descrição Rateio (da coluna O): Melissa
# Despesa Antecipada: Não
#
# Processando linha 3:
# Fornecedor: INTERNET LOJA RIDER SP
# Valor Total: 1.980,00
# Data Inicial:
# Data Final:
# Conta Contabil: Comunicacao de Dados - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): LINK DE INTERNET (CLARO e VIVO)
# Descrição Rateio (da coluna O): Loja Rider
# Despesa Antecipada: Não
#
# Processando linha 4:
# Fornecedor: INTERNET GALERIA MELISSA
# Valor Total: 18.000,00
# Data Inicial:
# Data Final:
# Conta Contabil: Comunicacao de Dados - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): LINK DE INTERNET (CLARO e VIVO)
# Descrição Rateio (da coluna O): Galeria melissa
# Despesa Antecipada: Não
#
# Processando linha 5:
# Fornecedor: INTERNET SOBRAL
# Valor Total: 213.840,00
# Data Inicial:
# Data Final:
# Conta Contabil: Comunicacao de Dados - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): LINKS DE INTERNET (CLARO, ALGAR, BRISANET e SOBRALNET)
# Descrição Rateio (da coluna O): Office 365 (só sobral) -  Quantidade sem promotor (24632534)
# Despesa Antecipada: Não
#
# Processando linha 6:
# Fornecedor: INTERNET FARROUPILHA
# Valor Total: 204.360,00
# Data Inicial:
# Data Final:
# Conta Contabil: Comunicacao de Dados - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): LINKS DE INTERNET (CLARO, ALGAR e BITCOM)
# Descrição Rateio (da coluna O): Office 365  (só farroupilha)- Quantidade sem promotor
# Despesa Antecipada: Não
#
# Processando linha 7:
# Fornecedor: INTERNET FORTALEZA
# Valor Total: 70.679,76
# Data Inicial:
# Data Final:
# Conta Contabil: Comunicacao de Dados - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): LINK DE INTERNET (CLARO, ALGAR  BRISANET)
# Descrição Rateio (da coluna O): Office 365 (só fortaleza) - Quantidade sem promotor
# Despesa Antecipada: Não
#
# Processando linha 8:
# Fornecedor: INTERNET CRATO
# Valor Total: 76.578,07
# Data Inicial:
# Data Final:
# Conta Contabil: Comunicacao de Dados - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): LINK DE INTERNET (CLARO, ALGAR e BRISANET)
# Descrição Rateio (da coluna O): Office 365 (só crato) - Quantidade sem promotor
# Despesa Antecipada: Não
#
# Processando linha 9:
# Fornecedor: X5 SOLUCOES TECNOLOGICAS LTDA
# Valor Total: 185.000,00
# Data Inicial: 13/03/2024
# Data Final: 19/03/2025
# Conta Contabil: Comunicacao de Dados - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): XCONTACT e SBC RIBBON CLOUD - são serviços de telefonia IP e Telefonia Teams, permitindo fazer e receber ligações locais, interurbanas e internacionais, com perfil Teams (Phone System), oferece mobilidade via smartphone ou notebook e funciona de qualquer lugar do mundo com internet, exemplo: home-office ou em viagens, reduzindo o custo com ligações externas via celular corporativo, serviços englobam todas unidades Grendene (FAR, SOB, FOR e CRA).
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: Sim
#
# Processando linha 10:
# Fornecedor: IS INFORMATICA SOFTWARE LTDA
# Valor Total: 346.452,00
# Data Inicial: 01/10/2022
# Data Final: 30/09/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Luciano Machado
# Observações (da coluna H): Plataforma de integração entre sistemas internos e externos.
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: Sim
#
# Processando linha 11:
# Fornecedor: INTELIGENCIA DE NEG SISTEMAS E INFO LTDA
# Valor Total: 592.572,00
# Data Inicial: 01/01/2024
# Data Final: 18/12/2024
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Luciano Machado
# Observações (da coluna H): Plataforma de BI/Analytics
# Descrição Rateio (da coluna O): Rateio QLIKVIEW
# Despesa Antecipada: Sim
#
# Processando linha 12:
# Fornecedor: OUTSYSTEMS BRASIL LTDA
# Valor Total: 3.581.176,97
# Data Inicial:
# Data Final: 24/06/2024
# Conta Contabil: IMOBILIZADO
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): Outsystems é hoje nossa principal ferreamente de desenvolvimento em low-code, possibilitando um ganho de performance no desenvolvimento de telas (front-end.) e também rotinas (back-end). Usamos esta ferramenta para sistemas simples e complexos como SIAG, Cromatografia, SGCP, TOTVS...
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: Sim
#
# Processando linha 13:
# Fornecedor: Senior
# Valor Total: 630.759,84
# Data Inicial: 01/07/2024
# Data Final: 01/07/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Cristina Ramos
# Observações (da coluna H): Plataforma de RH corporativa
# Descrição Rateio (da coluna O): Senior
# Despesa Antecipada: Não
#
# Processando linha 14:
# Fornecedor: PRIME CONTROL CONSULTORIA LTDA
# Valor Total: 152.926,08
# Data Inicial: 16/01/2024
# Data Final: 16/01/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Leandro Rasia
# Observações (da coluna H): Plataforma corporativa (Jira) para gestão de projetos e melhorias de sistemas.
# Descrição Rateio (da coluna O): TIFAR
# Despesa Antecipada: Sim
#
# Processando linha 15:
# Fornecedor: SERCOMPE COMPUTADORES LTDA
# Valor Total: 50.623,20
# Data Inicial:
# Data Final: 01/10/2026
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): SUPORTE PARA O
# Licenças do software de backup (Veeam)
# Servidores de backup
# Storage de Backup
# Descrição Rateio (da coluna O): TISERCOMPE
# Despesa Antecipada: Sim
#
# Processando linha 16:
# Fornecedor: CURUPIRA AS - Take blip
# Valor Total: 264.000,00
# Data Inicial: 01/08/2024
# Data Final: 01/08/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Leandro Rasia
# Observações (da coluna H): Plataforma de ChatBot.
# Descrição Rateio (da coluna O): Senioretake
# Senior+ 1000 Vendas PAGA
# Despesa Antecipada: Não
#
# Processando linha 17:
# Fornecedor: MIRO - Pagamento Bradesco Visa
# Valor Total: 62.700,00
# Data Inicial:
# Data Final: 01/10/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Leandro Rasia
# Observações (da coluna H): Plataforma suporta reuniões interativas, workshops, compartilhamento de ideias...
# Descrição Rateio (da coluna O): Miro
# Despesa Antecipada: Sim
#
# Processando linha 18:
# Fornecedor: GODADDY
# Valor Total: 2.600,00
# Data Inicial: 27/11/2023
# Data Final: 02/11/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Certificado Wildcard
# Descrição Rateio (da coluna O): 24890005
# Despesa Antecipada: Não
#
# Processando linha 19:
# Fornecedor: PPRO BRASIL LTDA
# Valor Total: 90.000,00
# Data Inicial: 05/07/2022
# Data Final: 04/06/2027
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Plataforma de atendimento (TeamViewer) disponível em todo os dispositivos.
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: Sim
#
# Processando linha 20:
# Fornecedor: SYSTEMS MANAGER- TECNOL EM INFORMATICA LTDA
# Valor Total: 9.551,89
# Data Inicial: 31/08/2024
# Data Final: 30/08/2027
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Red Hat Enterprise Linux Server, Standard (Physical or Virtual Nodes) -
# Descrição Rateio (da coluna O): TI far
# Despesa Antecipada: Sim
#
# Processando linha 21:
# Fornecedor: DINAMIO TECNOLOGIA
# Valor Total: 14.735,02
# Data Inicial: 14/08/2024
# Data Final: 14/08/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Cristina Ramos
# Observações (da coluna H): Contrato de manutenção do SGA→CORPIA.
# Descrição Rateio (da coluna O): TI Far
# Despesa Antecipada: Sim
#
# Processando linha 22:
# Fornecedor: SIEMENS INDUSTRY SOFTWARE LTDA
# Valor Total: 546.252,00
# Data Inicial:
# Data Final: 17/08/2024
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Francivaldo Brito
# Observações (da coluna H): Licença CAT10301-Softlines, Hardlines Footwear
# Licença TC033611 RFA Solution Author/PLM
# Licença TC033611 RFA Solution Author/PLM (Atualizção)
# Licença TC033612 RFA Solution Consumer/PLM-TC
# Licença TC033612-RFA Solution Consumer/PLM (Atualização)
# Licença TC10318 Teamcenter Gateway for Enterpris
# Licença TC10405 Teamcenter Open (SDK)/PLM-TC
# Licença TC1DOTC -Teamcenter Deployment/PLM-TC
# Licença TCM055000-Teamcenter Manufacturing Viewer
# Licença TCM055001- Teamcenter Manufacturing Assembly
# Licença TCM055005-Teamcenter Manufacturing Part User
# Descrição Rateio (da coluna O): Rateio PLM (pessoas com a licença)   (martim passa o rateio)
# Despesa Antecipada: Sim
#
# Processando linha 23:
# Fornecedor: CLC COMERCIO
# Valor Total: 34.929,21
# Data Inicial: 11/08/2023
# Data Final: 11/08/2024
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Cristina Ramos
# Observações (da coluna H): Software de planejamento orçamentário. (SYSPHERA)
# Descrição Rateio (da coluna O): sysphera
# Despesa Antecipada: Sim
#
# Processando linha 24:
# Fornecedor: Neoep Engenharia de Produção Ltda
# Valor Total: 186.572,40
# Data Inicial:
# Data Final: 31/12/2024
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Francivaldo Brito
# Observações (da coluna H): Plataforma de APS. Licenciamento da modelagem, licença perpetua
# Descrição Rateio (da coluna O): 20510003  135k
# MTZ FAR 20k 24200003
# ENG FAR 24k 24493003
# Despesa Antecipada: Sim
#
# Processando linha 25:
# Fornecedor: SMARTFORCE TECNOLOGIA
# Valor Total: 204.668,64
# Data Inicial: 20/07/2023
# Data Final: 19/07/2026
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Luciano Machado
# Observações (da coluna H): Plataforma de automação e hiper automação de processos. (automation anywhere)
# Descrição Rateio (da coluna O): Rateio próprio conforme o uso
# Despesa Antecipada: Sim
#
# Processando linha 26:
# Fornecedor: ROBOT EASY
# Valor Total: 58.800,00
# Data Inicial:
# Data Final:
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Luciano Machado
# Observações (da coluna H): Plataforma de automação e hiper automação de processos. (ROBOT EASY)
# Descrição Rateio (da coluna O): 50% 24750005
# 50% 20750005
# Despesa Antecipada: Sim
#
# Processando linha 27:
# Fornecedor: AGIDESK
# Valor Total: 171.913,44
# Data Inicial: 01/08/2024
# Data Final: 01/08/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Cristina Ramos
# Observações (da coluna H): Plataforma de gestão de chamados e demandas.
# Descrição Rateio (da coluna O): Office 365 (com promotor)
# Despesa Antecipada: sim
#
# Processando linha 28:
# Fornecedor: GS1
# Valor Total: 23.716,00
# Data Inicial: 24/01/2024
# Data Final: 15/10/2023
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Francivaldo Brito
# Observações (da coluna H): Autorização uso Código Barras
# Descrição Rateio (da coluna O): 100% Vendas (+- R$ $1849,50 maio +- R$ $1849,50 novembro)
# Despesa Antecipada: Não
#
# Processando linha 29:
# Fornecedor: Confluence
# Valor Total: 61.428,00
# Data Inicial: 01/09/2024
# Data Final: 01/09/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Leandro Rasia
# Observações (da coluna H): Base de conhecimento
# Descrição Rateio (da coluna O): 40% 24750005
# 40% 20750005                         20% 24752445
# Despesa Antecipada: Não
#
# Processando linha 30:
# Fornecedor: Monday
# Valor Total: 25.094,52
# Data Inicial: 24/01/2024
# Data Final: 21/09/2024
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Leandro Rasia
# Observações (da coluna H): Monday - gestão de projetos
# Descrição Rateio (da coluna O): Monday
# Despesa Antecipada: Não
#
# Processando linha 31:
# Fornecedor: TOTVS S.A_1
# Valor Total: 86.393,52
# Data Inicial:
# Data Final: 24/07/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): Manutenção de 47 Licenças de Acesso Integral ao Totvs
# Descrição Rateio (da coluna O): Rateio TOTVS
# Despesa Antecipada: Não
#
# Processando linha 32:
# Fornecedor: TOTVS S.A_2
# Valor Total: 1.620,75
# Data Inicial:
# Data Final:
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): Manutenção de 2161 Licenças de Acesso Integral ao Totvs
# Descrição Rateio (da coluna O): Rateio TOTVS
# Despesa Antecipada: Sim
#
# Processando linha 33:
# Fornecedor: TOTVS S.A_3
# Valor Total: 5.583,72
# Data Inicial:
# Data Final: 01/09/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): Manutenção para transmissão de 50 mil documentos mensais da Neogrid (atualmente trafegamos 185 mil documentos mensais, avaliar na próxima renovação a possibilidade de fazer uma melhor negociação)
# Descrição Rateio (da coluna O): Rateio TOTVS
# Despesa Antecipada: Não
#
# Processando linha 34:
# Fornecedor: TOTVS S.A_4
# Valor Total: 85.680,00
# Data Inicial:
# Data Final: 15/05/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): Licenciamento do Fluig (Central de Tarefas e armazenamento de arquivos das áreas) para 6152 usuários
# Descrição Rateio (da coluna O): Rateio TOTVS
# Despesa Antecipada: Não
#
# Processando linha 35:
# Fornecedor: TOTVS S.A_5 (não coloquei)
# Valor Total: 1,68
# Data Inicial:
# Data Final: 01/11/2022
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): Licenças para desenvolvimento no TOTVS ESB (avaliar a necessidade de mantermos essas licenças)
# Descrição Rateio (da coluna O): Rateio TOTVS
# Despesa Antecipada: Não
#
# Processando linha 36:
# Fornecedor: TOTVS S.A_6
# Valor Total: 3.052,80
# Data Inicial:
# Data Final: 14/05/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): Manutenção de 40 usuários para acesso ao banco de dados do ERP (usuários de tecnologia)
# Descrição Rateio (da coluna O): Rateio TOTVS
# Despesa Antecipada: Não
#
# Processando linha 37:
# Fornecedor: TOTVS S.A_7
# Valor Total: 523,20
# Data Inicial:
# Data Final: 14/05/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): Manutenção de 5 usuários para acesso ao banco de dados do ERP (usuários de tecnologia)
# Descrição Rateio (da coluna O): Rateio TOTVS
# Despesa Antecipada: Não
#
# Processando linha 38:
# Fornecedor: TOTVS S.A_8
# Valor Total: 1.252.847,16
# Data Inicial:
# Data Final: 14/05/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): Manutenção de:
# 318 Licenças de acesso ao Totvs;
# 1100 Licenças de banco de dados Progress;
# 80 Licenças de HCM;
# 698 Licenças de acesso via Internet ou Webservices;
# 1130 Licenças de Usuários Progress;
# 13 Licenças de Coletores de Dados;
# 318 Licenças de Acesso Integral Totvs FULL;
# Descrição Rateio (da coluna O): Rateio TOTVS
# Despesa Antecipada: Não e Sim
#
# Processando linha 39:
# Fornecedor: TOTVS S.A_9
# Valor Total: 296.141,96
# Data Inicial: 30/03/2024
# Data Final: 30/03/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): MANUTENÇÃO ANUAL DO PROGRESS REPLICADO
# Descrição Rateio (da coluna O): Rateio TOTVS
# Despesa Antecipada: Sim
#
# Processando linha 40:
# Fornecedor: TOTVS S.A_10
# Valor Total: 259.936,08
# Data Inicial:
# Data Final: 11/04/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): Manutenção de Licenças do WMS SAS
# Descrição Rateio (da coluna O): TotvsVMW
# Despesa Antecipada: Não
#
# Processando linha 41:
# Fornecedor: TOTVS S.A_11
# Valor Total: 49.334,40
# Data Inicial:
# Data Final: 11/04/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): Serviços Mensais de Software (SMSe) NEOGRID - SMS COLAB NEO 100.0000 DOC
# Descrição Rateio (da coluna O): Rateio TOTVS
# Despesa Antecipada: Não
#
# Processando linha 42:
# Fornecedor: Maker - Manutenção, Integração Totvs X EML, Integração ClearSale, Usuários e ConecteMe + BI
# Valor Total: 1.048.034,06
# Data Inicial: 01/06/2024
# Data Final: 01/05/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Rafael Machado
# Observações (da coluna H): MAKER - INTEGRAÇÃO OCC / HUB / CONECTEME / E-MILLENNIUM / GATEWAY DE FRETE - MAKER - INTEGRAÇÃO DE INFORMAÇÕES TOTVS X E-MILLENNIUM - MAKER - INTEGRAÇÃO CLEARSALE - ORACLE COMMERCE: SERVIÇOS DE SUPORTE E SUSTENTAÇÃO DA INTEGRAÇÃO A PARTIR DO VOLUME DE PEDIDOS TRANSACIONADOS - MAKER - SERVIÇOS DE SUSTENTAÇÃO CONTINUADA E SUPORTE DE USUÁRIOS  CONECTEME FLOW
# Descrição Rateio (da coluna O): DCG
# Despesa Antecipada: Não
#
# Processando linha 43:
# Fornecedor: Maker - Manutenção
# Valor Total: 136.978,20
# Data Inicial: 01/06/2024
# Data Final: 01/05/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Rafael Machado
# Observações (da coluna H):  MAKER - INTEGRAÇÃO OCC / HUB / CONECTEME / E-MILLENNIUM / GATEWAY DE FRETE
# Descrição Rateio (da coluna O): dcg
# Despesa Antecipada: Não
#
# Processando linha 44:
# Fornecedor: Maker - Integração Totvs X EML
# Valor Total: 10.032,00
# Data Inicial: 01/06/2024
# Data Final: 01/05/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Rafael Machado
# Observações (da coluna H): MAKER - INTEGRAÇÃO DE INFORMAÇÕES TOTVS X E-MILLENNIUM
# Descrição Rateio (da coluna O): dcg
# Despesa Antecipada: Não
#
# Processando linha 45:
# Fornecedor: Maker - Integração ClearSale
# Valor Total: 24.415,44
# Data Inicial: 01/06/2024
# Data Final: 01/01/1900
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Rafael Machado
# Observações (da coluna H): MAKER - INTEGRAÇÃO CLEARSALE - ORACLE COMMERCE: SERVIÇOS DE SUPORTE E SUSTENTAÇÃO DA INTEGRAÇÃO A PARTIR DO VOLUME DE PEDIDOS TRANSACIONADOS
# Descrição Rateio (da coluna O): dcg
# Despesa Antecipada: Não
#
# Processando linha 46:
# Fornecedor: Maker - Usuários
# Valor Total: 54.787,32
# Data Inicial: 01/06/2024
# Data Final: 01/05/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Rafael Machado
# Observações (da coluna H): MAKER - SERVIÇOS DE SUSTENTAÇÃO CONTINUADA E SUPORTE DE USUÁRIOS  CONECTEME FLOW
# Descrição Rateio (da coluna O): dcg
# Despesa Antecipada: Não
#
# Processando linha 47:
# Fornecedor: Privacy Tools
# Valor Total: 57.246,60
# Data Inicial: 01/08/2024
# Data Final: 08/02/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Rafael Machado
# Observações (da coluna H):  MENSALIDADE PRIVACY TOOLS SAAS - PLATAFORMA DE GERENCIAMENTO DA PRIVACIDADE. MODULOS: GESTÃO DE COOKIES & MONITORAMENTO DE SITE; GESTÃO DE POLÍTICAS; DSAR
# Descrição Rateio (da coluna O): dcg
# Despesa Antecipada: Não
#
# Processando linha 48:
# Fornecedor: Supermetrics
# Valor Total: 0,00
# Data Inicial:
# Data Final: 25/01/2024
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Fernanda Almeida
# Observações (da coluna H): CANCELADO
# Descrição Rateio (da coluna O): dcg
# Despesa Antecipada: Sim
#
# Processando linha 49:
# Fornecedor: BIT SERVICES
# Valor Total: 12.349,92
# Data Inicial: 14/04/2024
# Data Final: 01/04/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Rafael Machado
# Observações (da coluna H): Site Blindado | Serviço de Blindagem de Sites Premium para 3 URLs (" lojagrendene.com.br "  e  " melissa.com.br, rider.com.br") - Vigência 24 meses. Serviços:- 3 URLs inclusas no plano, com possibilidade de contratação de URLs adicionais com valor extra - Scan de aplicação- Scan de IP - Scan full de aplicação - Scan de API- Selo Site Blindado- 1 Quick Pentest.
# Descrição Rateio (da coluna O): 24570004 - 50%
# 24571384 - 50%
# Despesa Antecipada: Não
#
# Processando linha 50:
# Fornecedor: Oracle Responsys - B2B
# Valor Total: 6.179,64
# Data Inicial: 01/08/2022
# Data Final: 01/07/2031
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): utilizado para envio de e-mails para clientes que compraram no e-commerce da Rider, comunicando que o pedido foi recebido, aprovado, que foi realizado o faturamento, envio do produto, entre outros (chamados de e-mails transacionais)
# Descrição Rateio (da coluna O): oracleinsta
# Despesa Antecipada: Não
#
# Processando linha 51:
# Fornecedor: Oracle - Instância B2B
# Valor Total: 175.488,48
# Data Inicial: 01/08/2024
# Data Final: 01/08/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): Plataforma Oracle para a Venda no canal diamante para a DIV1 e Melissa
#
# Descrição Rateio (da coluna O): Oracleb2b
# Despesa Antecipada: sim
#
# Processando linha 52:
# Fornecedor: Linx_1
# Valor Total: 369.408,00
# Data Inicial:
# Data Final: 14/05/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Rafael Machado
# Observações (da coluna H): Renovação dos serviços Linx, conforme descrição abaixo:
# 1- LIC MENSAL HOSTING PREMIUM
# 14- LICENÇA MENSAL WMS SAAS
# 3- LIC MENSAL DEMAIS API SAAS
# 1- LIC MENSAL SERVIDOR FTP HOSTING
# 1- LIC MENSAL HOSTING
# 20- LICENÇA MENSAL WMS SAAS
# 10- LICENÇA MENSAL SIMULTANEO SAAS
# Descrição Rateio (da coluna O): linx1
# Despesa Antecipada: Não
#
# Processando linha 53:
# Fornecedor: Linx_2
# Valor Total: 467.360,76
# Data Inicial:
# Data Final: 05/10/2023
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Rafael Machado
# Observações (da coluna H): – Aluguel de +5 licenças do tipo API (para contemplar o maior volume de requisição no período de sazonalidade
# – Aluguel de +1 servidor de aplicação no período de sazonalidade (hoje temos 2 servers que trabalham no formato de “load balancer”).
# Descrição Rateio (da coluna O): linx1
# Despesa Antecipada: nan
#
# Processando linha 54:
# Fornecedor: Linx_3
# Valor Total: 49.416,00
# Data Inicial:
# Data Final: 26/08/2023
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Rafael Machado
# Observações (da coluna H): Linx Emillennium - Melhoria de infra estrutura. (REMOVER)
# Descrição Rateio (da coluna O): 24570004
# Despesa Antecipada: nan
#
# Processando linha 55:
# Fornecedor: Linx_4
# Valor Total: 52.416,00
# Data Inicial:
# Data Final: 14/05/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Rafael Machado
# Observações (da coluna H): LINX | Serviços de Servidor Pré Produção: 1VM de 4 CPUs  6GB RAM e 200GB de disco SSD + Servidor SQL Server com 4 CPUs 8GB RAM e 250GB de disco SSD. VIGENCIA 12 Meses (31/08/2023 a 30/08/2024). (REMOVIDO)
# Descrição Rateio (da coluna O): dcg
# Despesa Antecipada: nan
#
# Processando linha 56:
# Fornecedor: GitHub
# Valor Total: 5.261,57
# Data Inicial: 01/09/2024
# Data Final: 01/09/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Rafael Machado
# Observações (da coluna H): Período: 1 Ano
# Plano: Team
# Quantidade de Licenças: 15
# Valor Total: $ 960/ano * 5,49 = R$ 5.261,57 (cotação do dólar com base no dia 26/08/2024)
#  Licença Expira em: 02/09/2024
# OBS: No momento da renovação devemos entrar em contato com Caio Diodi Fernandes, pois não temos acesso a conta.
#  Link de referência:https://github.com/pricing#compare-features
# Descrição Rateio (da coluna O): 24752445
# Despesa Antecipada: Não
#
# Processando linha 57:
# Fornecedor: CloudFlare
# Valor Total: 11.000,00
# Data Inicial:
# Data Final: 08/03/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Rafael Machado
# Observações (da coluna H): Licenças Pro
# Descrição Rateio (da coluna O): 24752445
# Despesa Antecipada: Não
#
# Processando linha 58:
# Fornecedor: INGRAM
# Valor Total: 99.940,60
# Data Inicial:
# Data Final: 30/07/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): nan
# Observações (da coluna H): Licenças Renovação do Suporte IBM Cloud Pak for Business Automation V
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: Não
#
# Processando linha 59:
# Fornecedor: D4SING
# Valor Total: 18.009,00
# Data Inicial: 01/01/2024
# Data Final: 01/01/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Cristina Ramos
# Observações (da coluna H): Investimento por 500 requisições mês
# Descrição Rateio (da coluna O): D4SIGN
# Despesa Antecipada: Sim
#
# Processando linha 60:
# Fornecedor: DINAMIO TECNOLOGIA 2
# Valor Total: 10.770,00
# Data Inicial: 03/08/2024
# Data Final: 02/08/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Cristina Ramos
# Observações (da coluna H): Suporte e sustentação
# Descrição Rateio (da coluna O): 24750005
# Despesa Antecipada: Não
#
# Processando linha 61:
# Fornecedor: FLUID
# Valor Total: 115.000,00
# Data Inicial: 01/06/2024
# Data Final: 01/06/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Cristina Ramos
# Observações (da coluna H): Software para gestão de performance de pessoas
# Descrição Rateio (da coluna O): Senior
# Despesa Antecipada: Não
# Erro ao formatar data '31/04/2025': day is out of range for month, at position 0
#
# Processando linha 62:
# Fornecedor: DataDog
# Valor Total: 43.591,44
# Data Inicial: 01/05/2024
# Data Final:
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Rafael Machado
# Observações (da coluna H): renovação da ferramenta Datadog que vai expirar no dia 31/04/2024
#
# Essa ferramenta serve para observabilidade dos ambientes do Ecommerce, afim de gerar alertas quando ocorre indisponibilidade e intermitências. Por se tratar de um ambiente de Ecommerce, cada minuto fora significa faturamento parado, dessa forma, a ferramenta ajuda a rápida ação dos analistas e identificação de problemas.
#
# Proposta em anexo, favor considerar cenário 1 (de menor valor).
#
# Centro de custo: 24750005
#
# Vigência: 12 meses
#
# Valor: US$ 16,448 x5 = R$82.240
#
#
#
# Manutenções Aplicativos
#
# &#10070; Utilização: 419
#
# &#10070; Tipo de Despesa: 178
#
# &#10070; Conta contábil: 3.3.01.15.01.01.010
#
#
#
# Jan/2023 - Dez/2023:  54.337,50
# Jan/2024 - Mar/2024:  23.287,50
#
# centro de custo do DCG: 24752445
# Descrição Rateio (da coluna O): 24752445
# Despesa Antecipada: Não
#
# Processando linha 63:
# Fornecedor: Paytrack
# Valor Total: 172.808,64
# Data Inicial: 01/08/2024
# Data Final: 01/07/2025
# Conta Contabil: Manutenções Aplicativos - TI
# Responsável (da coluna I): Cristina Ramos
# Observações (da coluna H): Sistema de prestação de contas e gestão de despesas em viagens corporativas
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: Sim
#
# Processando linha 64:
# Fornecedor: TOTVS S.A
# Valor Total: 296.141,96
# Data Inicial: 30/03/2024
# Data Final: 30/03/2025
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Martim Crema
# Observações (da coluna H): Sistema de armazenamento dos dados corporativos do ERP TOTVS.
# Descrição Rateio (da coluna O): Rateio TOTVS
# Despesa Antecipada: Sim
#
# Processando linha 65:
# Fornecedor: MAC - TOTVS S.A
# Valor Total: 168.000,00
# Data Inicial: 06/06/2024
# Data Final: 06/06/2025
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Suporte em nosso ambiente corporativo de banco de dados do ERP TOTVS, realizando manutenções, atualizações, migração de versão, backups, tunning e outros
# Descrição Rateio (da coluna O): Rateio TOTVS
# Despesa Antecipada: Não
#
# Processando linha 66:
# Fornecedor: LHC - TOTVS S.A
# Valor Total: 99.996,00
# Data Inicial: 01/12/2023
# Data Final: 01/12/2024
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Suporte em nosso ambiente corporativo de banco de dados do ERP TOTVS, realizando manutenções, atualizações, migração de versão, backups, tunning e outros
# Descrição Rateio (da coluna O): Rateio TOTVS
# Despesa Antecipada: Não
#
# Processando linha 67:
# Fornecedor: QRIAR TECNOLOGIA LTDA
# Valor Total: 490.893,50
# Data Inicial: 20/05/2024
# Data Final: 19/05/2025
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Serviço para garantir a segurança de acesso a internet entre usuários e provedores de serviços.  (CASB)
# Descrição Rateio (da coluna O): Office 365 - Quantidade com promotor
# Despesa Antecipada: Sim
#
# Processando linha 68:
# Fornecedor: PROCESSOR INFORMATICA S/A
# Valor Total: 332.979,35
# Data Inicial: 30/06/2023
# Data Final: 30/06/2026
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Plataforma corporativa do office 365 (Teams, Word, Excel, PowerPoint, SharePoint, OneDrive....)
# Descrição Rateio (da coluna O): Office 365 - Valores
# Despesa Antecipada: Sim
#
# Processando linha 69:
# Fornecedor: PROCESSOR MAX SERV E SOLUCOES EM TI LTDA (redução de 50% do valor do contrato)
# Valor Total: 43.223,57
# Data Inicial: 25/06/2024
# Data Final: 26/06/2025
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Atendimento avançado do office365 e interação com Microsoft.
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: Sim
#
# Processando linha 70:
# Fornecedor: PROCESSOR INFORMATICA S/A
# Valor Total: 30.023,10
# Data Inicial: 01/03/2023
# Data Final: 28/02/2026
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Ferramenta para desenvolvimento de soluções como SIS, SCC, Reserva Refeição, SGA que usam .Net
# Descrição Rateio (da coluna O): 20750005
# Despesa Antecipada: nan
#
# Processando linha 71:
# Fornecedor: SANTODIGITAL DISTRIBUIO E CONSULTORIA EM
# Valor Total: 1.596.900,00
# Data Inicial: 30/12/2022
# Data Final: 01/12/2025
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Serviço de hospedagem, armazenamento e processamentos de dados.
# Descrição Rateio (da coluna O): Santodigital
# Despesa Antecipada: Não
#
# Processando linha 72:
# Fornecedor: BENCE - antigo Yssy
# Valor Total: 573.600,00
# Data Inicial: 26/09/2024
# Data Final: 26/09/2025
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Plataforma de Next Gen SIEM Exabeam e Yssy Smart SOC -  Correlação de Logs e atendimento 24 x 7 eventos de segurança
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: Sim
#
# Processando linha 73:
# Fornecedor: REDBELT SECURITY SISTEMAS E SOLUCOES DE SEGURANCA DIGITAL
# Valor Total: 27.276,24
# Data Inicial: 10/02/2023
# Data Final: 10/02/2025
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Ferramenta que analisa todo o ambiente de TI em busca de falhas de segurança, incluindo infraestrutura, dispositivos, servidores e aplicações e busca por falta de atualizações, erros de configuração em equipamentos/redes.
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: Sim
#
# Processando linha 74:
# Fornecedor: L5 NETWORKS COMERCIO EM TELECOM
# Valor Total: 28.710,00
# Data Inicial: 01/08/2023
# Data Final: 01/08/2024
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Plataforma de integração das vídeos conferências com o TEAMS
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: nan
#
# Processando linha 75:
# Fornecedor: OP SERVICES TECNOLOGIA DA INFORMACAO
# Valor Total: 93.631,50
# Data Inicial: 31/08/2024
# Data Final: 31/08/2026
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): OPMON -Plataforma de monitoramento do ambiente corporativo Grendene (aps, ar condicionado, servidores, câmeras, rede, CD, 2D....)
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: Sim
#
# Processando linha 76:
# Fornecedor: ABC TECHNOLOGY SERVICES INC 1
# Valor Total: 41.019,41
# Data Inicial: 01/03/2024
# Data Final: 01/03/2025
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Plataforma para auditoria e monitoramento da rede (azurre, controle de domínio e file server)
# Descrição Rateio (da coluna O): TI far
# Despesa Antecipada: Sim
#
# Processando linha 77:
# Fornecedor: ABC TECHNOLOGY SERVICES INC 2
# Valor Total: 285.434,26
# Data Inicial: 01/06/2024
# Data Final: 01/09/2027
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Solução integrada (Desktop Central) de gerenciamento de dispositivos móveis e desktops que atende a todas as necessidades de gerenciamento corporativo
# Descrição Rateio (da coluna O): Office 365 - Quantidade com promotor
# Despesa Antecipada: Sim
#
# Processando linha 78:
# Fornecedor: ABC TECHNOLOGY SERVICES INC
# Valor Total: 0,00
# Data Inicial:
# Data Final:
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Licenciamento de software do Desktop Central para 950 computadores do Simon ( JUNTO COM O DE CIMA)
# Descrição Rateio (da coluna O): JUNTO COM O DE CIMA
# Despesa Antecipada: Sim
#
# Processando linha 79:
# Fornecedor: HSC DESENVOLVIMENTO SERVICOS LTDA
# Valor Total: 113.403,00
# Data Inicial: 01/11/2023
# Data Final: 01/11/2024
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Plataforma de segurança de e-mails corporativos. (validar numero na renovação, atual 5500)
# Descrição Rateio (da coluna O): Office 365 - Quantidade com promotor
# Despesa Antecipada: Sim
#
# Processando linha 80:
# Fornecedor: NET E CO COM E SERV INFORMATICA LTDA
# Valor Total: 43.341,00
# Data Inicial: 01/06/2024
# Data Final: 01/06/2026
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Sistema inteligente de permissionamento sem a necessidade de conhecimento das senhas corporativas
# Descrição Rateio (da coluna O): TIfar
# Despesa Antecipada: Sim
#
# Processando linha 81:
# Fornecedor: NET E CO COM E SERV INFORMATICA LTDA
# Valor Total: 6.750,00
# Data Inicial: 01/06/2024
# Data Final: 01/06/2026
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Sistema inteligente de permissionamento sem a necessidade de conhecimento das senhas corporativas
# Descrição Rateio (da coluna O): TIfar
# Despesa Antecipada: Sim
#
# Processando linha 82:
# Fornecedor: MACRIUM
# Valor Total: 21.875,00
# Data Inicial: 30/04/2024
# Data Final: 01/05/2025
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Serviço de backup de imagens dos discos rígidos de máquinas corporativas
# Descrição Rateio (da coluna O): Macrium
# Despesa Antecipada: Sim
#
# Processando linha 83:
# Fornecedor: INTEGRASUL SOLUCOES EM INFORMATICA LTDA
# Valor Total: 11.130,40
# Data Inicial: 01/09/2022
# Data Final: 01/09/2023
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Suporte ao Antivírus Trend Micro (CANCELADO)
# Descrição Rateio (da coluna O): TI
# Despesa Antecipada: Sim
#
# Processando linha 84:
# Fornecedor: SCANSOURCE BRASIL
# Valor Total: 574.536,13
# Data Inicial:
# Data Final: 20/06/2027
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): VORN0177 - Trend Vision One Email and Collaboration Security
# AXRN0004 - Vision One XDR Add-on: Email Normal Renew - Detec
# VORN0046 - Trend Vision One - Endpoint Security (Essentials)
# VONN0164 - Trend Vision One Attack Surface Risk Management N
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: Sim
#
# Processando linha 85:
# Fornecedor: SCANSOURCE BRASIL
# Valor Total: 0,00
# Data Inicial: 30/06/2023
# Data Final:
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): JUNTO COM O DE CIMA
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: sim
#
# Processando linha 86:
# Fornecedor: WAF SUCURI
# Valor Total: 35.000,00
# Data Inicial:
# Data Final:
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): WAF (Firewall de aplicações Web) utilizado para proteger sites da Grendene e das marcas que ficam expostos na internet. Ele faz todo o filtro para proteger estes sites e aplicações de ataques.
# Descrição Rateio (da coluna O): 40% 24750005
# 30% 20750005
# 15% 21750005
# 15% 40750005
# Despesa Antecipada: Não
#
# Processando linha 87:
# Fornecedor: GLOBAL 1
# Valor Total: 97.363,44
# Data Inicial: 23/11/2022
# Data Final: 21/06/2027
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Serviço de manutenção para garantir a continuidade e eficiência da rede corporativa.
# Aruba 5y FC NBD 5710 - HQ5V6E -Aruba 5Y FC NBD 594x - HQ5Y4E
# Descrição Rateio (da coluna O): global
# Despesa Antecipada: Sim
#
# Processando linha 88:
# Fornecedor: GLOBAL 2
# Valor Total: 50.627,00
# Data Inicial: 23/11/2022
# Data Final: 21/06/2027
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H):  CONTRATO DE EXTENSÃO DE GARANTIA CORE E TOR CLEAR PASS
# Descrição Rateio (da coluna O): Globaltor (office)
# Despesa Antecipada: Sim
#
# Processando linha 89:
# Fornecedor: GLOBAL 3
# Valor Total: 9.077,52
# Data Inicial: 01/03/2024
# Data Final: 01/02/2025
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Suporte a RENOVAÇÃO SUPORTE TÉCNICO PLATINUM FULL 24X7 - PACOTE DE 50 HORAS ANO
# Descrição Rateio (da coluna O): Tifar
# Despesa Antecipada: Sim
#
# Processando linha 90:
# Fornecedor: PBI
# Valor Total: 66.912,00
# Data Inicial: 06/10/2023
# Data Final: 01/10/2024
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Suporte 24x7 aos equipamentos Fortinet (Firewalls, FortiAuthenticator, FortiAnalyzer) os quais são utilizados para efetuar a segurança de perímetro das redes da Grendene, bem como acesso VPN e roteamento.
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: Sim
# Erro ao formatar data 'CANCELADO': Unknown datetime string format, unable to parse: CANCELADO, at position 0
#
# Processando linha 91:
# Fornecedor: BEAN SOFTWARES LTDA
# Valor Total: 48.000,00
# Data Inicial: 01/01/2023
# Data Final:
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Francivaldo Brito
# Observações (da coluna H): Ferramenta  para otimização de relatórios, automatizando informações compiladas em templates definidos pelo usuário, com o intuito de agilizar processos com foco na alta performance. (CANCELADO)
# Descrição Rateio (da coluna O): 20030141 - 20,00%
# 20050511 - 10,00%
# 20060131 - 10,00%
# 20070131 - 10,00%
# 20080003 - 10,00%
# 20490003 - 30,00%
# 20750005 - 10,00%
# Despesa Antecipada: Não
#
# Processando linha 92:
# Fornecedor: F5 SOFTWARE
# Valor Total: 13.200,00
# Data Inicial: 11/10/2023
# Data Final: 11/10/2024
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Capta o sinal do Wifi e faz um mapeamento de calor do status do sinal.
# Descrição Rateio (da coluna O): tifar
# Despesa Antecipada: Sim
#
# Processando linha 93:
# Fornecedor: Ingram Micro Brasil Ltda
# Valor Total: 475.295,28
# Data Inicial: 19/09/2023
# Data Final: 19/09/2025
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Controlador de ameaças pelo trafego da Internet em conjunto com a VPN. SWG
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: Sim
#
# Processando linha 94:
# Fornecedor: Addon Endpoint(junto com o contrato da ABC TECHNOLOGY SERVICES INC)
# Valor Total: 73.776,24
# Data Inicial:
# Data Final:
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): nan
# Observações (da coluna H): junto com o contrato da ABC TECHNOLOGY SERVICES INC
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: nan
#
# Processando linha 95:
# Fornecedor: ViaFlow
# Valor Total: 30.260,88
# Data Inicial: 01/07/2024
# Data Final: 01/07/2024
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Cristina Ramos
# Observações (da coluna H): Serviço de desenvolvimento e suporte de ferramentas da IBM (ECM/BPM/RPA)
# R$2500,00 mensal + SobDemanda.
# Descrição Rateio (da coluna O): 24750005
# Despesa Antecipada: Não
#
# Processando linha 96:
# Fornecedor: IBM
# Valor Total: 99.940,60
# Data Inicial: 01/07/2024
# Data Final: 01/07/2025
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Cristina Ramos
# Observações (da coluna H): Suporte e atualizações
# Descrição Rateio (da coluna O): 24750005
# Despesa Antecipada: Não
#
# Processando linha 97:
# Fornecedor: Contratos
# Valor Total: 500.000,00
# Data Inicial:
# Data Final:
# Conta Contabil: Manutenções Sistemas Operacionais - TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Projetos novos de segurança
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: nan
#
# Processando linha 98:
# Fornecedor: IK1 SERVICE LTDA
# Valor Total: 57.406,34
# Data Inicial: 28/12/2022
# Data Final: 27/12/2024
# Conta Contabil: Garantia Estendida Equip Informatica -TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Equipamentos responsáveis por balancear os acessos aos sistemas Grendene entre os servidores disponíveis, melhorando a performance e disponibilidade)
# (NF: 66 - Seriais Números : BAR-BF-1532140 / BAR-BF-1529109.) (NF 67 Seriais Numbers : BAR-BF- 386182 / BAR-BF- 1527950)
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: sim
#
# Processando linha 99:
# Fornecedor: SERCOMPE COMPUTADORES LTDA_1
# Valor Total: 392.204,76
# Data Inicial: 14/05/2023
# Data Final: 13/05/2025
# Conta Contabil: Garantia Estendida Equip Informatica -TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Renovação Contrato Suporte e garantia dos equipamentos HP (8 switches SAN  e 02 Storage 3Par 8400)
# Nros séries Switches: USB210V001,USB210V002,USB210V003,USB210V005,USB310V026,USB310V027,USB310V02A,USB310V02B
#
# Nros séries Storages:  3Par 8400, Series 2MK6150368, 2MK6140351
# Descrição Rateio (da coluna O): Rateio do office
# Despesa Antecipada: sim
#
# Processando linha 100:
# Fornecedor: SERCOMPE HARDWARE RESELLER LTDA_2
# Valor Total: 14.407,69
# Data Inicial: 01/07/2022
# Data Final: 30/06/2025
# Conta Contabil: Garantia Estendida Equip Informatica -TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): REF RENOVAÇÃO DE GARANTIAS DOS SERVIDORES HP - FORTALEZA
# PART NUMBER: 686792-B21 - SERIAL NUMBER: BRC4204W15
# PART NUMBER: 686792-B21 - SERIAL NUMBER: BRC4204W17
# Descrição Rateio (da coluna O): 21750005
# Despesa Antecipada: sim
#
# Processando linha 101:
# Fornecedor: SERCOMPE HARDWARE RESELLER LTDA_3
# Valor Total: 14.407,69
# Data Inicial: 01/07/2022
# Data Final: 30/06/2025
# Conta Contabil: Garantia Estendida Equip Informatica -TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): REF RENOVAÇÃO DE GARANTIAS DOS SERVIDORES HP - CRATO
# PART NUMBER: 686792-B21 - SERIAL NUMBER: BRC4204W16
# PART NUMBER: 686792-B21 - SERIAL NUMBER: BRC4204W18
# Descrição Rateio (da coluna O): 40750005
# Despesa Antecipada: sim
#
# Processando linha 102:
# Fornecedor: SERCOMPE HARDWARE RESELLER LTDA_4
# Valor Total: 13.298,99
# Data Inicial: 01/05/2023
# Data Final: 01/05/2025
# Conta Contabil: Garantia Estendida Equip Informatica -TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): REF. RENOVAÇÃO GARANTIA SERVIDORES HP DL380G7 CTO
# Serial: BRC216124J e BRC216124K
# Descrição Rateio (da coluna O): 24750005
# Despesa Antecipada: sim
#
# Processando linha 103:
# Fornecedor: SERCOMPE HARDWARE RESELLER LTDA_5
# Valor Total: 46.492,61
# Data Inicial: 09/01/2023
# Data Final: 08/01/2026
# Conta Contabil: Garantia Estendida Equip Informatica -TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Renovacao servidores PROCTI,13,14,15,16 de Farroupilha, cfe patrimônios abaixo:
# Serie BRC7489C1H, bem 45859
# Serie BRC7489C1L, bem 45864
# Serie BRC7489C1J, bem 45860
# Serie BRC7489C1K, bem 45862
# Descrição Rateio (da coluna O): officesempromotor
# Despesa Antecipada: sim
#
# Processando linha 104:
# Fornecedor: DELL COMPUTADORES DO BRASIL LTDA_1
# Valor Total: 25.920,00
# Data Inicial: 01/07/2023
# Data Final: 31/07/2025
# Conta Contabil: Garantia Estendida Equip Informatica -TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Renovação garantia para o Servidor R920 e R740 séries:
# 51L4Y02 – BEM 42416 - Farroupilha
# 21L4Y02 – BEM 42422 - Farroupilha
# 31L4Y02 – BEM 42421 - Farroupilha
# 41L4Y02 – BEM 42420 - Farroupilha
# J0L4Y02 – BEM 42415 - Farroupilha
# 61L4Y02 – BEM 42418 - Farroupilha
# 11L4Y02 – BEM 42419 - Farroupilha
# F0L4Y02 – BEM 42417 - Farroupilha
# CP3WWQ2 - BEM 47795 - Farroupilha
# CP2YWQ2 – BEM 47794 - Farroupilha
# Descrição Rateio (da coluna O): 24750005
# Despesa Antecipada: sim
#
# Processando linha 105:
# Fornecedor: DELL COMPUTADORES DO BRASIL LTDA_2
# Valor Total: 52.177,85
# Data Inicial: 26/10/2022
# Data Final: 25/10/2024
# Conta Contabil: Garantia Estendida Equip Informatica -TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Renovação da garantia para STORAGE SERVER EMC² VNX 5200 serie CKM00143700456 patrimonio 36896, CKM00143700630 patrimonio 36895 - Vigencia 02 anos (25/10/2022 a 25/10/2024).
# Descrição Rateio (da coluna O): Rateio atualizado após o planejamento
# Despesa Antecipada: sim
#
# Processando linha 106:
# Fornecedor: DELL COMPUTADORES DO BRASIL LTDA_3
# Valor Total: 32.387,80
# Data Inicial: 25/10/2022
# Data Final: 25/10/2023
# Conta Contabil: Garantia Estendida Equip Informatica -TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): →Renovação da garantia para SWITCH EMC² DS-300Bsérie: BRCALJ1909Q006 patrimonio 36898 - Vigencia 01 ano (25/10/2022 a 25/10/2023).
# →Renovação da garantia para SWITCH EMC² DS-300B série:  BRCALJ1932K05X patrimonio 36897 - Vigencia 01 ano (25/10/2022 a 25/10/2023).
# →Renovação da garantia para SWITCH EMC² DS-300B série: BRCALJ1932K06A patrimonio 36899 - Vigencia 01 ano (25/10/2022 a 25/10/2023)
# →Renovação da garantia para SWITCH EMC² DS-300B série: BRCALJ4018P058 patrimonio 36900 - Vigencia 01 ano (25/10/2022 a 25/10/2023).
# Descrição Rateio (da coluna O): Rateio atualizado após o planejamento
# Despesa Antecipada: sim
#
# Processando linha 107:
# Fornecedor: EVERNEX B EQUIPAMENTOS DE INFORMATICA_1
# Valor Total: 114.851,71
# Data Inicial: 15/09/2023
# Data Final: 17/09/2025
# Conta Contabil: Garantia Estendida Equip Informatica -TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): RENOVAÇÃO STORAGE 3PAR 7400 Controller (248xHPE 450GB 10000RPM SAS 6Gbps 2.5-inch- PN HCBRE0450GBAS10k.
#
# RENOVAÇÃO de UNIDADES DE BACKUP E SERVIDORES TESTES PROCTI11 e PROCTI12 E BACKUP (DPMASRVFAR01, e DPMASRVFAR02),CONTEMPLANDO SERVIDORES MODELOS DL980 G7, séries TWT301007R;TWT3010080, SERVIDORES MODELO 360 G9,series BRC5296PL4,BRC5296PL5, E LIBRARY MSL 4048 (4XLTO6), séries HUJ5233WMH,HUJ5233WN2,HUJ5233WVH,HUJ5243YNK, HUJ5243YPP,HUJ5243YU8,HUJ5243YUC,HUJ5243YWA,MXA525Z09K,MXA525707D.
#
# Contratação Garantia para os Servidores PROCTI, 1 e 2, marca HP Modelo DL580 G7, series BRC21715KJ e  BRC21715KK, patrimônio 33920 e 33921
# Descrição Rateio (da coluna O): Rateio do office
# Despesa Antecipada: sim
#
# Processando linha 108:
# Fornecedor: EVERNEX B EQUIPAMENTOS DE INFORMATICA_2
# Valor Total: 8.263,95
# Data Inicial: 15/09/2023
# Data Final: 18/09/2025
# Conta Contabil: Garantia Estendida Equip Informatica -TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): CRATO:
# 1- HP SRV DL380p Gen8 - SERIAL: BR34746MD -  BEM: 036839
# 2- HP SRV DL380p Gen8 -SERIAL: BRC34746ME - BEM: 036840
#
# SOBRAL:
# 1- VWTSCEN011 - HP SRV DL380p Gen8 - SERIAL : BRC24124M6 - BEM :34826
# 2- VWTSRH02 - HP SRV DL380p Gen8 - SERIAL : BRC24124M7 - BEM: 34909
#
# FORTALEZA:
# 1- vwtscenfor01 - HP SRV DL380p Gen8 -SERIAL: BRC34746LR - BEM:  36753
# 2- vwtscenfor02  - HP SRV DL380p Gen8 - SERIAL: BRC34746LP -BEM: 38762
# Descrição Rateio (da coluna O): TI
# 20750005 - 33%
# 21750005 - 33%
# 40750005 - 33%
# Despesa Antecipada: Não
#
# Processando linha 109:
# Fornecedor: EVERNEX B EQUIPAMENTOS DE INFORMATICA_3
# Valor Total: 1.721,52
# Data Inicial: 15/09/2023
# Data Final: 19/09/2025
# Conta Contabil: Garantia Estendida Equip Informatica -TI
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Servidor DL560 Gen8 CTO Serve, Part-number 686792-B21,séries BRC4204W14 que suportam as aplicações corporativas da empresa utilizado no Ambiente VmWare (27 servidores virtuais), BEM: 40555
# Descrição Rateio (da coluna O): 20750005
# Despesa Antecipada: Não
#
# Processando linha 110:
# Fornecedor: FS TECNOLOGIA TREINAMENTO
# Valor Total: 88.900,00
# Data Inicial: 02/08/2022
# Data Final: 01/08/2023
# Conta Contabil: Treinamento
# Responsável (da coluna I): Andre Felipe Grehs
# Observações (da coluna H): Programa conscientização segurança da Informação (ESKIVE)
# Descrição Rateio (da coluna O): Office 365 - Quantidade sem promotor
# Despesa Antecipada: sim
# C:\Users\lz6321\AppData\Local\Temp\ipykernel_15796\999940445.py:118: UserWarning: Parsing dates in %d/%m/%Y	 format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data = pd.to_datetime(data_str)
# ✅ Arquivo processado salvo em: C:\Users\lz6321\Downloads\contratos_processados.xlsx
#
# Primeiras linhas do arquivo gerado:
#               nome_contrato           nome_fornecedor  \
# 0                   Locaweb                   Locaweb
# 1           FAPESP / NIC.BR           FAPESP / NIC.BR
# 2               101 Domains               101 Domains
# 3    INTERNET LOJA RIDER SP    INTERNET LOJA RIDER SP
# 4  INTERNET GALERIA MELISSA  INTERNET GALERIA MELISSA
#
#               conta_contabil status vigencia data_inicial  data_final  \
# 0  Comunicacao de Dados - TI  ATIVO                        19/10/2023
# 1  Comunicacao de Dados - TI  ATIVO
# 2  Comunicacao de Dados - TI  ATIVO
# 3  Comunicacao de Dados - TI  ATIVO
# 4  Comunicacao de Dados - TI  ATIVO
#
#   valor_total         responsavel vertical  \
# 0   90.000,00  Andre Felipe Grehs
# 1    3.900,00  Andre Felipe Grehs
# 2    2.912,00  Andre Felipe Grehs
# 3    1.980,00  Andre Felipe Grehs
# 4   18.000,00  Andre Felipe Grehs
#
#                                 descricao despesa_antecipada    frequencia  \
# 0  Sites e Domínios de internet das áreas          Sim e não         Anual
# 1  Sites e Domínios de internet das áreas                Não  Pontualmente
# 2  Sites e Domínios de internet das áreas                Não  Pontualmente
# 3  Contrato de Internet para loja/unidade                Não         Anual
# 4  Contrato de Internet para loja/unidade                Não         Anual
#
#                                          observacoes  \
# 0  Hospedagem Servidores + registro domínios naci...
# 1  Hospedagem Servidores + registro domínios naci...
# 2                 Domínios internacionais da Melissa
# 3                    LINK DE INTERNET (CLARO e VIVO)
# 4                    LINK DE INTERNET (CLARO e VIVO)
#
#                                     descricao_rateio
# 0                           34% MKT 33% DVE  33% EXP
# 1  Conforme necessidade do setor se vai querer re...
# 2                                            Melissa
# 3                                         Loja Rider
# 4                                    Galeria melissa
#
# Primeiras linhas do arquivo gerado:
#               nome_contrato           nome_fornecedor  \
# 0                   Locaweb                   Locaweb
# 1           FAPESP / NIC.BR           FAPESP / NIC.BR
# 2               101 Domains               101 Domains
# 3    INTERNET LOJA RIDER SP    INTERNET LOJA RIDER SP
# 4  INTERNET GALERIA MELISSA  INTERNET GALERIA MELISSA
#
#               conta_contabil status vigencia data_inicial  data_final  \
# 0  Comunicacao de Dados - TI  ATIVO                        19/10/2023
# 1  Comunicacao de Dados - TI  ATIVO
# 2  Comunicacao de Dados - TI  ATIVO
# 3  Comunicacao de Dados - TI  ATIVO
# 4  Comunicacao de Dados - TI  ATIVO
#
#   valor_total         responsavel vertical  \
# 0   90.000,00  Andre Felipe Grehs
# 1    3.900,00  Andre Felipe Grehs
# 2    2.912,00  Andre Felipe Grehs
# 3    1.980,00  Andre Felipe Grehs
# 4   18.000,00  Andre Felipe Grehs
#
#                                 descricao despesa_antecipada    frequencia  \
# 0  Sites e Domínios de internet das áreas          Sim e não         Anual
# 1  Sites e Domínios de internet das áreas                Não  Pontualmente
# 2  Sites e Domínios de internet das áreas                Não  Pontualmente
# 3  Contrato de Internet para loja/unidade                Não         Anual
# 4  Contrato de Internet para loja/unidade                Não         Anual
#
#                                          observacoes  \
# 0  Hospedagem Servidores + registro domínios naci...
# 1  Hospedagem Servidores + registro domínios naci...
# 2                 Domínios internacionais da Melissa
# 3                    LINK DE INTERNET (CLARO e VIVO)
# 4                    LINK DE INTERNET (CLARO e VIVO)
#
#                                     descricao_rateio
# 0                           34% MKT 33% DVE  33% EXP
# 1  Conforme necessidade do setor se vai querer re...
# 2                                            Melissa
# 3                                         Loja Rider
# 4                                    Galeria melissa
